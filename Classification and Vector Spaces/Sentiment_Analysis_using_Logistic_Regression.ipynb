# %% [markdown]
# ##**Import Functions and Data**

# %%
import nltk
from os import getcwd

# %%
filepath = f"{getcwd()}/../tmp/"
nltk.data.path.append(filepath)

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import twitter_samples

from utils import process_tweet, build_freqs
nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ###**Prepare the data**

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %%
# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# %%
len(train_x), len(test_x)
# Out:
# (8000, 2000)

# %%
# Create the numpy array of positive labels and negative labels.
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis = 0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis = 0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# Check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11337

# %% [markdown]
# ###**Process Tweet**

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# ##**1. Logistic regression**

# %% [markdown]
# <a name='1-1'></a>
# ###1.1 Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='./images/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %%
def sigmoid(z):
  '''
  Input:
    z: is the input (can be a scalar or an array)
  Output:
    h: the sigmoid of z
  '''
  h = 1 / (1 + np.exp(-z))

  return h

# %%
# Testing our function
if (sigmoid(0) == 0.5):
  print("SUCCESS !")
else:
  print("Oops")

if (sigmoid(4.92) == 0.9927537604041685):
  print("Correct !")
else:
  print("Oops again")
# Out:
# SUCCESS !
# Correct !

# %% [markdown]
# ####1.1 Logistic Regression: Regression and a Sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the deep learning specialization, we referred to the weights with the 'w' vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# <a name='1-2'></a>
# ### 1.2 - Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of training example 'i'.
# * $h(z^{(i)})$ is the model's prediction for the training example 'i'.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label 'y' is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # Loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x^{(i)}_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x^{(i)}_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# ##**2. Gradient Descent**

# %% [markdown]
# <a name='ex-2'></a>
# Implement gradient descent function.
# * The number of iterations 'num_iters" is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are 'm' training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %%
def gradientdescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    # get 'm', the number of rows in matrix x
    m = x.shape[0]

    for i in range(0, num_iters):

        # get z, the dot product of x and theta
        z = np.dot(x,theta)

        # get the sigmoid of z
        h = sigmoid(z)

        # calculate the cost function
        J = -1./m * (np.dot(y.transpose(), np.log(h)) + np.dot((1-y).transpose(),np.log(1-h)))

        # update the weights theta
        theta = theta = theta - (alpha/m) * np.dot(x.transpose(),(h-y))

    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)

# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis = 1)

# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientdescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# <ipython-input-18-6de6a7d90e55>:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   J = float(J)

# %% [markdown]
# ##**Extract Features**

# %%
def extract_features(tweet, freqs):
    '''
    Input:
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output:
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_1 = process_tweet(tweet)

    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3))

    #bias term is set to 1
    x[0, 0] = 1

    # loop through each word in the list of words
    for word in word_1:
        # increment the word count for the positive label 1
        x[0, 1] += freqs.get((word, 1.0), 0)

        # increment the word count for the negative label 0
        x[0, 2] += freqs.get((word, 0.0), 0)

    assert(x.shape == (1, 3))
    return x

# %%
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# [[1.00e+00 3.02e+03 6.10e+01]]

# %%
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1. 0. 0.]]

# %% [markdown]
# ##**Training your model**

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
  X[i, :] = extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientdescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# The cost after training is 0.24215478.
# The resulting vector of weights is [7e-08, 0.00052391, -0.00055517]
# <ipython-input-18-6de6a7d90e55>:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   J = float(J)

# %% [markdown]
# ##**Test your Logisitc Regression**

# %%
def predict_tweet(tweet, freqs, theta):
    '''
    Input:
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output:
        y_pred: the probability of a tweet being positive or negative
    '''

    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)

    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))

    return y_pred

# %%
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.518581
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530899
# great great great -> 0.546274
# great great great great -> 0.561562
# <ipython-input-26-c05f05402b44>:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))

# %%
my_tweet = 'I am learning :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.8163691]])

# %% [markdown]
# ###**Check performance using the test set**

# %%
def test_logistic_regression(test_x, test_y, freqs, theta):
    """
    Input:
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output:
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    # the list for storing predictions
    y_hat = []

    for tweet in test_x:
      # get the label prediction for the tweet
      y_pred = predict_tweet(tweet, freqs, theta)

      if y_pred > 0.5:
        # append 1.0 to the list
        y_hat.append(1)
      else:
        # append 0 to the list
        y_hat.append(0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator

    accuracy = (y_hat == np.squeeze(test_y)).sum()/len(test_x)

    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.9950

# %% [markdown]
# ###**Error Analysis**

# %%
# Some error analysis done
print('Label Predicted tweet')
for x, y in zip(test_x, test_y):
  y_hat = predict_tweet(x, freqs, theta)

  if np.abs(y - (y_hat > 0.05)) > 0:
    print('THE TWEET IS:', x)
    print('THE PROCESSED TWEET IS:', process_tweet(x))
    print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted tweet
# THE TWEET IS: @AndreaMarySmith very helpful .... Or will be once I stop crying :(
# THE PROCESSED TWEET IS: ['help', '...', 'stop', 'cri', ':(']
# 0	0.10858459	b'help ... stop cri :('
# THE TWEET IS: @realyys_ OTL NEVERMIND :( at least i got jeon so
# THE PROCESSED TWEET IS: ['otl', 'nevermind', ':(', 'least', 'got', 'jeon']
# 0	0.11368699	b'otl nevermind :( least got jeon'
# THE TWEET IS: And AS SOON as I tweeted that she planted her claws in my thigh for traction and zoomed away :(
# THE PROCESSED TWEET IS: ['soon', 'tweet', 'plant', 'claw', 'thigh', 'traction', 'zoom', 'away', ':(']
# 0	0.11585098	b'soon tweet plant claw thigh traction zoom away :('
# THE TWEET IS: @luketothestars damnit :(
# THE PROCESSED TWEET IS: ['damnit', ':(']
# 0	0.11577318	b'damnit :('
# THE TWEET IS: @KLM I used to be PRY/PV ..... wish I could relive those days and become NYC/PV buy there is no way to communicate with NYC or USA KLM :(
# THE PROCESSED TWEET IS: ['use', 'pri', 'pv', '...', 'wish', 'could', 'reliv', 'day', 'becom', 'nyc', 'pv', 'buy', 'way', 'commun', 'nyc', 'usa', 'klm', ':(']
# 0	0.11374281	b'use pri pv ... wish could reliv day becom nyc pv buy way commun nyc usa klm :('
# THE TWEET IS: It's really hot :-(
# THE PROCESSED TWEET IS: ['realli', 'hot', ':-(']
# 0	0.44349756	b'realli hot :-('
# THE TWEET IS: @Carouselballet Monday? :(
# THE PROCESSED TWEET IS: ['monday', ':(']
# 0	0.11575078	b'monday :('
# THE TWEET IS: @badoeuf If going to stop breakfast early you might want to remove the 11am from your website. Even McD's doesn't pull that trick. :(
# THE PROCESSED TWEET IS: ['go', 'stop', 'breakfast', 'earli', 'might', 'want', 'remov', '11am', 'websit', 'even', "mcd'", 'pull', 'trick', ':(']
# 0	0.10361005	b"go stop breakfast earli might want remov 11am websit even mcd' pull trick :("
# THE TWEET IS: @blairforce2 which means its on its way over here :( 3rd load just hung up
# THE PROCESSED TWEET IS: ['mean', 'way', ':(', '3rd', 'load', 'hung']
# 0	0.11418587	b'mean way :( 3rd load hung'
# THE TWEET IS: :( but wtf am I supposed to do now without her
# THE PROCESSED TWEET IS: [':(', 'wtf', 'suppos', 'without']
# 0	0.11470013	b':( wtf suppos without'
# THE TWEET IS: Headache strike :(
# THE PROCESSED TWEET IS: ['headach', 'strike', ':(']
# 0	0.11548613	b'headach strike :('
# THE TWEET IS: English weather needs to fix up :((
# THE PROCESSED TWEET IS: ['english', 'weather', 'need', 'fix', ':(']
# 0	0.11299862	b'english weather need fix :('
# THE TWEET IS: Live fam bam but I have a cough :(
# THE PROCESSED TWEET IS: ['live', 'fam', 'bam', 'cough', ':(']
# 0	0.11765227	b'live fam bam cough :('
# THE TWEET IS: Absolutely gutted all the James Bay tickets have sold out for Manchester :(
# THE PROCESSED TWEET IS: ['absolut', 'gut', 'jame', 'bay', 'ticket', 'sold', 'manchest', ':(']
# 0	0.11523639	b'absolut gut jame bay ticket sold manchest :('
# THE TWEET IS: Seventh spot na lang :( #OTWOLGrandTrailer
# THE PROCESSED TWEET IS: ['seventh', 'spot', 'na', 'lang', ':(', 'otwolgrandtrail']
# 0	0.11477557	b'seventh spot na lang :( otwolgrandtrail'
# THE TWEET IS: Splendour :(
# THE PROCESSED TWEET IS: ['splendour', ':(']
# 0	0.11577318	b'splendour :('
# THE TWEET IS: @lizzytrevaskis @1057darwin OMG! Swedish hair metal legends HäirFørce in the studio while I am on leave??? Noooo :( #givecodpieceachance
# THE PROCESSED TWEET IS: ['omg', 'swedish', 'hair', 'metal', 'legend', 'häirførc', 'studio', 'leav', 'nooo', ':(', 'givecodpieceach']
# 0	0.11137244	b'omg swedish hair metal legend hirfrc studio leav nooo :( givecodpieceach'
# THE TWEET IS: @missalicebmbds it's sore, Alice. :(
# THE PROCESSED TWEET IS: ['sore', 'alic', ':(']
# 0	0.11602558	b'sore alic :('
# THE TWEET IS: I'm not ready to work yet :(
# THE PROCESSED TWEET IS: ["i'm", 'readi', 'work', 'yet', ':(']
# 0	0.10705166	b"i'm readi work yet :("
# THE TWEET IS: @adoringpreston someone unfaved :((
# THE PROCESSED TWEET IS: ['someon', 'unfav', ':(']
# 0	0.11505714	b'someon unfav :('
# THE TWEET IS: stiles :(
# THE PROCESSED TWEET IS: ['stile', ':(']
# 0	0.11577318	b'stile :('
# THE TWEET IS: @infinityandbion funny mo :(
# THE PROCESSED TWEET IS: ['funni', 'mo', ':(']
# 0	0.11634516	b'funni mo :('
# THE TWEET IS: someone explain #SandraBland :(
# THE PROCESSED TWEET IS: ['someon', 'explain', 'sandrabland', ':(']
# 0	0.11493777	b'someon explain sandrabland :('
# THE TWEET IS: @archietalanay dont be sad :(((((( ily
# THE PROCESSED TWEET IS: ['dont', 'sad', ':(', 'ili']
# 0	0.10906809	b'dont sad :( ili'
# THE TWEET IS: @sonzhi No, I am going to spend the night in Prague and then leaving tomorrow :(
# THE PROCESSED TWEET IS: ['go', 'spend', 'night', 'pragu', 'leav', 'tomorrow', ':(']
# 0	0.11178349	b'go spend night pragu leav tomorrow :('
# THE TWEET IS: one of my friend is following me , a little heart attack , im sorry youre blocked :((((( sadis
# THE PROCESSED TWEET IS: ['one', 'friend', 'follow', 'littl', 'heart', 'attack', 'im', 'sorri', 'your', 'block', ':(', 'sadi']
# 0	0.10700791	b'one friend follow littl heart attack im sorri your block :( sadi'
# THE TWEET IS: @ellierowexo no I'm annoyed :(
# THE PROCESSED TWEET IS: ["i'm", 'annoy', ':(']
# 0	0.10805122	b"i'm annoy :("
# THE TWEET IS: @GabyInTheFields Consider yourself lucky! my favourite character didn't even make it to the season finale in The 100 :(
# THE PROCESSED TWEET IS: ['consid', 'lucki', 'favourit', 'charact', 'even', 'make', 'season', 'final', '100', ':(']
# 0	0.11204375	b'consid lucki favourit charact even make season final 100 :('
# THE TWEET IS: @SarahLucero boo. I had already turned in. Yes. At 915. :(
# THE PROCESSED TWEET IS: ['boo', 'alreadi', 'turn', 'ye', '915', ':(']
# 0	0.11525242	b'boo alreadi turn ye 915 :('
# THE TWEET IS: @BeaMiller I DON'T HAVE ITUNES SO I'M WAITING #NotAnApology :(
# THE PROCESSED TWEET IS: ['itun', "i'm", 'wait', 'notanapolog', ':(']
# 0	0.10922265	b"itun i'm wait notanapolog :("
# THE TWEET IS: my layout doesn't match but it's the closest I could find for my header :( someone help
# THE PROCESSED TWEET IS: ['layout', 'match', 'closest', 'could', 'find', 'header', ':(', 'someon', 'help']
# 0	0.11148481	b'layout match closest could find header :( someon help'
# THE TWEET IS: @Mjbulanhagui13 agh, sorry :-(
# THE PROCESSED TWEET IS: ['agh', 'sorri', ':-(']
# 0	0.43326170	b'agh sorri :-('
# THE TWEET IS: @Quality_CE don't gas me :((
# THE PROCESSED TWEET IS: ['ga', ':(']
# 0	0.11593418	b'ga :('
# THE TWEET IS: @TheKelseeey awhhh ok ok :( see you nalang when class opens!!! Hehe
# THE PROCESSED TWEET IS: ['awhhh', 'ok', 'ok', ':(', 'see', 'nalang', 'class', 'open', 'hehe']
# 0	0.11851565	b'awhhh ok ok :( see nalang class open hehe'
# THE TWEET IS: Last night was one of the worst night :( I pretty sure this Albanian women cursed me
# THE PROCESSED TWEET IS: ['last', 'night', 'one', 'worst', 'night', ':(', 'pretti', 'sure', 'albanian', 'women', 'curs']
# 0	0.11544817	b'last night one worst night :( pretti sure albanian women curs'
# THE TWEET IS: Air Max Tavas pls pls pls pls :(
# THE PROCESSED TWEET IS: ['air', 'max', 'tava', 'pl', 'pl', 'pl', 'pl', ':(']
# 0	0.11186480	b'air max tava pl pl pl pl :('
# THE TWEET IS: @ChaeHyungwon_ taken :( another chara maybe? -teteh
# THE PROCESSED TWEET IS: ['taken', ':(', 'anoth', 'chara', 'mayb', 'teteh']
# 0	0.11515431	b'taken :( anoth chara mayb teteh'
# THE TWEET IS: @devjoshi10 dev I.m verry sad cause you on twitter and than me off :(
# THE PROCESSED TWEET IS: ['dev', 'verri', 'sad', 'caus', 'twitter', ':(']
# 0	0.11062939	b'dev verri sad caus twitter :('
# THE TWEET IS: @ryannhough I can imagine! This would shatter my dreams :-( We'll let our @CooperativeFood colleagues know all about this. ^SB
# THE PROCESSED TWEET IS: ['imagin', 'would', 'shatter', 'dream', ':-(', "we'll", 'let', 'colleagu', 'know', 'sb']
# 0	0.45406693	b"imagin would shatter dream :-( we'll let colleagu know sb"
# THE TWEET IS: Too much missing you :(
# THE PROCESSED TWEET IS: ['much', 'miss', ':(']
# <ipython-input-31-bcb4e04f4119>:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# 0	0.10128608	b'much miss :('
# THE TWEET IS: @IMJicellmoreno Nawee ! :(
# THE PROCESSED TWEET IS: ['nawe', ':(']
# 0	0.11577318	b'nawe :('
# THE TWEET IS: I WANT A WHITE FRENCH BULLDOG :(((
# THE PROCESSED TWEET IS: ['want', 'white', 'french', 'bulldog', ':(']
# 0	0.10905676	b'want white french bulldog :('
# THE TWEET IS: Wanna feel loved :(
# THE PROCESSED TWEET IS: ['wanna', 'feel', 'love', ':(']
# 0	0.11777288	b'wanna feel love :('
# THE TWEET IS: @WeeklyChris Aww Poor you T.T I wish I was there to help you. Even though I can't really help much :(
# THE PROCESSED TWEET IS: ['aww', 'poor', 'wish', 'help', 'even', 'though', "can't", 'realli', 'help', 'much', ':(']
# 0	0.09739760	b"aww poor wish help even though can't realli help much :("
# THE TWEET IS: I'm sorry I didn't see this tweet :( 2 Points x https://t.co/N6HMgKfoR1
# THE PROCESSED TWEET IS: ["i'm", 'sorri', 'see', 'tweet', ':(', '2', 'point', 'x']
# 0	0.10699660	b"i'm sorri see tweet :( 2 point x"
# THE TWEET IS: I miss the Macho Man :(
# THE PROCESSED TWEET IS: ['miss', 'macho', 'man', ':(']
# 0	0.10323346	b'miss macho man :('
# THE TWEET IS: can i hav my purity back ? :(
# THE PROCESSED TWEET IS: ['hav', 'puriti', 'back', ':(']
# 0	0.11412580	b'hav puriti back :('
# THE TWEET IS: @heartissoJEDlag i have kwento :( fbc
# THE PROCESSED TWEET IS: ['kwento', ':(', 'fbc']
# 0	0.11565957	b'kwento :( fbc'
# THE TWEET IS: 3 days without talking with Bae :(
# THE PROCESSED TWEET IS: ['3', 'day', 'without', 'talk', 'bae', ':(']
# 0	0.11808016	b'3 day without talk bae :('
# THE TWEET IS: @punkrockbgmouth @indiandeathlock whaaaaaaat noooooooo :(
# THE PROCESSED TWEET IS: ['whaaat', 'nooo', ':(']
# 0	0.11503640	b'whaaat nooo :('
# THE TWEET IS: @WeeklyChris
#
# Please tweet me something I'm sad :( you can cheer me up
# please..
# THE PROCESSED TWEET IS: ['pleas', 'tweet', 'someth', "i'm", 'sad', ':(', 'cheer', 'pleas', '..']
# 0	0.08902829	b"pleas tweet someth i'm sad :( cheer pleas .."
# THE TWEET IS: I miss my brown hair :(
# THE PROCESSED TWEET IS: ['miss', 'brown', 'hair', ':(']
# 0	0.10310539	b'miss brown hair :('
# THE TWEET IS: Nakakapikon yung nagbabasa ka ng blog comments for info and it's full of people asking the same damned questions answered in the post. :(
# THE PROCESSED TWEET IS: ['nakakapikon', 'yung', 'nagbabasa', 'ka', 'ng', 'blog', 'comment', 'info', 'full', 'peopl', 'ask', 'damn', 'question', 'answer', 'post', ':(']
# 0	0.11698357	b'nakakapikon yung nagbabasa ka ng blog comment info full peopl ask damn question answer post :('
# THE TWEET IS: @kevinperry leading cause of cancer in children under five :(
# THE PROCESSED TWEET IS: ['lead', 'caus', 'cancer', 'children', 'five', ':(']
# 0	0.11588932	b'lead caus cancer children five :('
# THE TWEET IS: Alone :-( :'( :-\
# THE PROCESSED TWEET IS: ['alon', ':-(', ":'(", ':-\\']
# 0	0.44443541	b"alon :-( :'( :-\\"
# THE TWEET IS: @rcdlccom hello, any info about possible interest in Jonathas ?? He is close to join Betis :( greatings
# THE PROCESSED TWEET IS: ['hello', 'info', 'possibl', 'interest', 'jonatha', 'close', 'join', 'beti', ':(', 'great']
# 0	0.12646926	b'hello info possibl interest jonatha close join beti :( great'
# THE TWEET IS: @chescaleigh I'm sorry people are being shits who don't respect your personal space. :(
# THE PROCESSED TWEET IS: ["i'm", 'sorri', 'peopl', 'shit', 'respect', 'person', 'space', ':(']
# 0	0.10096141	b"i'm sorri peopl shit respect person space :("
# THE TWEET IS: @seulgi_psv noooo :( *sogok ice cream*
# THE PROCESSED TWEET IS: ['nooo', ':(', 'sogok', 'ice', 'cream']
# 0	0.11270185	b'nooo :( sogok ice cream'
# THE TWEET IS: @lucyanne_l Thank you for sending premium writing instrument, however some dastardly swine stole it from envelope! :( http://t.co/xNe3cD6dvk
# THE PROCESSED TWEET IS: ['thank', 'send', 'premium', 'write', 'instrument', 'howev', 'dastardli', 'swine', 'stole', 'envelop', ':(']
# 0	0.14010558	b'thank send premium write instrument howev dastardli swine stole envelop :('
# THE TWEET IS: Im getting sick and tired of pipol saying Im short... M not Short... I AM TINY :(
# THE PROCESSED TWEET IS: ['im', 'get', 'sick', 'tire', 'pipol', 'say', 'im', 'short', '...', 'short', '...', 'tini', ':(']
# 0	0.09569504	b'im get sick tire pipol say im short ... short ... tini :('
# THE TWEET IS: @Charlie_Bread fair enough :( why would anyone do that? Just seems a tad fucked up 😔 .. It's a wiper, a wiper!
# THE PROCESSED TWEET IS: ['fair', 'enough', ':(', 'would', 'anyon', 'seem', 'tad', 'fuck', '😔', '..', 'wiper', 'wiper']
# 0	0.11376127	b'fair enough :( would anyon seem tad fuck  .. wiper wiper'
# THE TWEET IS: @EMPERYtech supposedly one of the worst kernels for any device :(
# THE PROCESSED TWEET IS: ['supposedli', 'one', 'worst', 'kernel', 'devic', ':(']
# 0	0.11350278	b'supposedli one worst kernel devic :('
# THE TWEET IS: i'm so bored :(
# THE PROCESSED TWEET IS: ["i'm", 'bore', ':(']
# 0	0.10787877	b"i'm bore :("
# THE TWEET IS: Is this true? I doubt it is :( #ZaynIsComingBackOnJuly26
# THE PROCESSED TWEET IS: ['true', 'doubt', ':(', 'zayniscomingbackonjuli', '26']
# 0	0.11361761	b'true doubt :( zayniscomingbackonjuli 26'
# THE TWEET IS: Today’s job (another facking #Intel). Extra mega careful not to get bent socket pins :-( #PCGaming #PCUpgrade http://t.co/VeJNS9FBfn
# THE PROCESSED TWEET IS: ['today', '’', 'job', 'anoth', 'fack', 'intel', 'extra', 'mega', 'care', 'get', 'bent', 'socket', 'pin', ':-(', 'pcgame', 'pcupgrad']
# 0	0.44672359	b'today  job anoth fack intel extra mega care get bent socket pin :-( pcgame pcupgrad'
# THE TWEET IS: Hate being the messenger :(
# THE PROCESSED TWEET IS: ['hate', 'messeng', ':(']
# 0	0.11365855	b'hate messeng :('
# THE TWEET IS: is everyone asleep already?:((((
# THE PROCESSED TWEET IS: ['everyon', 'asleep', 'alreadi', ':(']
# 0	0.11526276	b'everyon asleep alreadi :('
# THE TWEET IS: @MoKurd they've brainwashed you :(
# THE PROCESSED TWEET IS: ["they'v", 'brainwash', ':(']
# 0	0.11560279	b"they'v brainwash :("
# THE TWEET IS: can some1 pls download smosh:the movie free online? Hahahaha :(
# THE PROCESSED TWEET IS: ['1', 'pl', 'download', 'smosh', 'movi', 'free', 'onlin', 'hahahaha', ':(']
# 0	0.11741310	b'1 pl download smosh movi free onlin hahahaha :('
# THE TWEET IS: MY kik - plawnew837 #kik #kikmenow #amateur #sfs #snapme #summer #hottie :( http://t.co/2HnzstgnOa
# THE PROCESSED TWEET IS: ['kik', 'plawnew', '837', 'kik', 'kikmenow', 'amateur', 'sf', 'snapm', 'summer', 'hotti', ':(']
# 0	0.11071714	b'kik plawnew 837 kik kikmenow amateur sf snapm summer hotti :('
# THE TWEET IS: @rivverofhoney Omg no way?! not you guys aswell :-( btw cat litter isnt good for pregnancy make sure u dont go near
# THE PROCESSED TWEET IS: ['omg', 'way', 'guy', 'aswel', ':-(', 'btw', 'cat', 'litter', 'isnt', 'good', 'pregnanc', 'make', 'sure', 'u', 'dont', 'go', 'near']
# 0	0.43727127	b'omg way guy aswel :-( btw cat litter isnt good pregnanc make sure u dont go near'
# THE TWEET IS: Ah Mensch @Tikus09 :(
# THE PROCESSED TWEET IS: ['ah', 'mensch', ':(']
# 0	0.11556444	b'ah mensch :('
# THE TWEET IS: Sepanx with this one :( https://t.co/4Hp6d3sMwr
# THE PROCESSED TWEET IS: ['sepanx', 'one', ':(']
# 0	0.11396307	b'sepanx one :('
# THE TWEET IS: @LoseThe_Battle We cannot view the picture. Are you unhappy with the seats on our bus? :(
# THE PROCESSED TWEET IS: ['cannot', 'view', 'pictur', 'unhappi', 'seat', 'bu', ':(']
# 0	0.11540631	b'cannot view pictur unhappi seat bu :('
# THE TWEET IS: There's a huge bag of presents from Luke and I can't open them until he's back from work :-((((
# THE PROCESSED TWEET IS: ["there'", 'huge', 'bag', 'present', 'luke', "can't", 'open', "he'", 'back', 'work', ':-(']
# 0	0.42347281	b"there' huge bag present luke can't open he' back work :-("
# THE TWEET IS: @baexrv pcy mine :-(
# THE PROCESSED TWEET IS: ['pci', 'mine', ':-(']
# 0	0.44777995	b'pci mine :-('
# THE TWEET IS: @walesdotcom @Visitcaerphilly last time I went to Caerphilly I couldn't find anywhere selling local cheese :-(
# THE PROCESSED TWEET IS: ['last', 'time', 'went', 'caerphilli', 'find', 'anywher', 'sell', 'local', 'chees', ':-(']
# 0	0.43461630	b'last time went caerphilli find anywher sell local chees :-('
# THE TWEET IS: My eyes are really bad today and I don't even have my glasses :(
# THE PROCESSED TWEET IS: ['eye', 'realli', 'bad', 'today', 'even', 'glass', ':(']
# 0	0.10941452	b'eye realli bad today even glass :('
# THE TWEET IS: @rauhlstilinski I'M OMW😍 lol I wish :(((((
# THE PROCESSED TWEET IS: ["i'm", 'omw', '😍', 'lol', 'wish', ':(']
# 0	0.10728954	b"i'm omw  lol wish :("
# THE TWEET IS: @lukesdagger JOKE LANG EH :( HAHDHDHSHHS
# THE PROCESSED TWEET IS: ['joke', 'lang', 'eh', ':(', 'hahdhdhshh']
# 0	0.11530654	b'joke lang eh :( hahdhdhshh'
# THE TWEET IS: Never seeing your dad until midnight bc he worked hard as fuck :( #GrowingUpPoor
# THE PROCESSED TWEET IS: ['never', 'see', 'dad', 'midnight', 'bc', 'work', 'hard', 'fuck', ':(', 'growinguppoor']
# 0	0.11164782	b'never see dad midnight bc work hard fuck :( growinguppoor'
# THE TWEET IS: @JackJackJohnson @jackgilinsky NUMBER ONE IN AMERICA!! 😭🇺🇸
# i wish i could buy it but no money :( http://t.co/7xyNmimTpR
# THE PROCESSED TWEET IS: ['number', 'one', 'america', '😭', '🇺🇸', 'wish', 'could', 'buy', 'money', ':(']
# 0	0.10871167	b'number one america   wish could buy money :('
# THE TWEET IS: Wish that I can buy all Bangtan's merch :(
# THE PROCESSED TWEET IS: ['wish', 'buy', "bangtan'", 'merch', ':(']
# 0	0.11345551	b"wish buy bangtan' merch :("
# THE TWEET IS: The pain of all #UberIceCream drivers being busy :(
# THE PROCESSED TWEET IS: ['pain', 'ubericecream', 'driver', 'busi', ':(']
# 0	0.11400326	b'pain ubericecream driver busi :('
# THE TWEET IS: @lawrenceispichu oh gosh what did you say? And aw hun :( *cuddles*
# THE PROCESSED TWEET IS: ['oh', 'gosh', 'say', 'aw', 'hun', ':(', 'cuddl']
# 0	0.11134234	b'oh gosh say aw hun :( cuddl'
# THE TWEET IS: @DatMelvin @Official__Jakub me wants! :(
# THE PROCESSED TWEET IS: ['want', ':(']
# 0	0.10913199	b'want :('
# THE TWEET IS: @taimoor_mahmood taimoor Meray dost :(
# THE PROCESSED TWEET IS: ['taimoor', 'meray', 'dost', ':(']
# 0	0.11577318	b'taimoor meray dost :('
# THE TWEET IS: @literalwt tyas mind to refollow me :(
# THE PROCESSED TWEET IS: ['tya', 'mind', 'refollow', ':(']
# 0	0.11624390	b'tya mind refollow :('
# THE TWEET IS: My stomach is killing me :(
# THE PROCESSED TWEET IS: ['stomach', 'kill', ':(']
# 0	0.11485742	b'stomach kill :('
# THE TWEET IS: as if not an apology isn't available in australia :(( @BeaMiller
# THE PROCESSED TWEET IS: ['apolog', 'avail', 'australia', ':(']
# 0	0.11567478	b'apolog avail australia :('
# THE TWEET IS: ksoo u dumb butt :(
# THE PROCESSED TWEET IS: ['ksoo', 'u', 'dumb', 'butt', ':(']
# 0	0.11443535	b'ksoo u dumb butt :('
# THE TWEET IS: i want to finish death parade by this weekend :(
# THE PROCESSED TWEET IS: ['want', 'finish', 'death', 'parad', 'weekend', ':(']
# 0	0.11134009	b'want finish death parad weekend :('
# THE TWEET IS: I'm so frustrated with my planks. The times are super inconsistent, and I have no idea what I'm doing wrong. :(
# THE PROCESSED TWEET IS: ["i'm", 'frustrat', 'plank', 'time', 'super', 'inconsist', 'idea', "i'm", 'wrong', ':(']
# 0	0.09983662	b"i'm frustrat plank time super inconsist idea i'm wrong :("
# THE TWEET IS: RIP TOM MOORE...... I LOVE READING HIS COMIC BOOKS....
# ANOTHER GREAT ARTIST I WILL TRULY MISS  :( http://t.co/f5uVxTUcSE
# THE PROCESSED TWEET IS: ['rip', 'tom', 'moor', '...', 'love', 'read', 'comic', 'book', '...', 'anoth', 'great', 'artist', 'truli', 'miss', ':(']
# 0	0.11230882	b'rip tom moor ... love read comic book ... anoth great artist truli miss :('
# THE TWEET IS: @tylerftirwin I miss this so much :(
# THE PROCESSED TWEET IS: ['miss', 'much', ':(']
# 0	0.10128608	b'miss much :('
# THE TWEET IS: @catasrtophe awww i miss you too i swear but Twitter these days are truly boring so i rather watch movies and football :(
# THE PROCESSED TWEET IS: ['awww', 'miss', 'swear', 'twitter', 'day', 'truli', 'bore', 'rather', 'watch', 'movi', 'footbal', ':(']
# 0	0.10467078	b'awww miss swear twitter day truli bore rather watch movi footbal :('
# THE TWEET IS: when can sch get better........ :-(
# THE PROCESSED TWEET IS: ['sch', 'get', 'better', '...', ':-(']
# 0	0.43564341	b'sch get better ... :-('
# THE TWEET IS: my throat is so so sore :((
# THE PROCESSED TWEET IS: ['throat', 'sore', ':(']
# 0	0.11552688	b'throat sore :('
# THE TWEET IS: Why is no one awake :(
# THE PROCESSED TWEET IS: ['one', 'awak', ':(']
# 0	0.11393781	b'one awak :('
# THE TWEET IS: Im hungry now :(
# THE PROCESSED TWEET IS: ['im', 'hungri', ':(']
# 0	0.11112505	b'im hungri :('
# THE TWEET IS: Get in the bin, OSX/Chrome/Voiceover &gt;:( http://t.co/0bcvA6YjWu
# THE PROCESSED TWEET IS: ['get', 'bin', 'osx', 'chrome', 'voiceov', '>:(']
# 0	0.49052265	b'get bin osx chrome voiceov >:('
# THE TWEET IS: 😂😂 what a night :(((((( so devo xxx https://t.co/9ixTnyBXLb
# THE PROCESSED TWEET IS: ['😂', '😂', 'night', ':(', 'devo', 'xxx']
# 0	0.11668171	b'  night :( devo xxx'
# THE TWEET IS: im so sad :(
# THE PROCESSED TWEET IS: ['im', 'sad', ':(']
# 0	0.10659258	b'im sad :('
# THE TWEET IS: I hope it's wrong about #HulkHogan but I think I know deep down its not. It's hurtful to wake up that kind of unpleasantness :(
# THE PROCESSED TWEET IS: ['hope', 'wrong', 'hulkhogan', 'think', 'know', 'deep', 'hurt', 'wake', 'kind', 'unpleas', ':(']
# 0	0.11327275	b'hope wrong hulkhogan think know deep hurt wake kind unpleas :('
# THE TWEET IS: @Yoonginese I don't even know what to say :(((
# THE PROCESSED TWEET IS: ['even', 'know', 'say', ':(']
# 0	0.11404296	b'even know say :('
# THE TWEET IS: @kingsxcreed daaaaaamn :((
# THE PROCESSED TWEET IS: ['daaamn', ':(']
# 0	0.11577318	b'daaamn :('
# THE TWEET IS: @maaaybs Grabe ang harsh huhuhu why u like that? :(
# THE PROCESSED TWEET IS: ['grabe', 'ang', 'harsh', 'huhuhu', 'u', 'like', ':(']
# 0	0.11366998	b'grabe ang harsh huhuhu u like :('
# THE TWEET IS: @halfmoonhalsey aw babe :((
# THE PROCESSED TWEET IS: ['aw', 'babe', ':(']
# 0	0.11365855	b'aw babe :('
# THE TWEET IS: @OscarTrue89 no sorry I'm fully booked :-( xx
# THE PROCESSED TWEET IS: ['sorri', "i'm", 'fulli', 'book', ':-(', 'xx']
# 0	0.41729967	b"sorri i'm fulli book :-( xx"
# THE TWEET IS: @ssulstagram why you unfollow me unnie?:(
# THE PROCESSED TWEET IS: ['unfollow', 'unni', ':(']
# 0	0.11817927	b'unfollow unni :('
# THE TWEET IS: @norman__g lucky spike only :-(
# THE PROCESSED TWEET IS: ['lucki', 'spike', ':-(']
# 0	0.44698733	b'lucki spike :-('
# THE TWEET IS: @imaginIarry omg i miss you 2 :(
# THE PROCESSED TWEET IS: ['omg', 'miss', '2', ':(']
# 0	0.10215200	b'omg miss 2 :('
# THE TWEET IS: Why didn't Panic's new album come out on the 22nd :(
# THE PROCESSED TWEET IS: ["panic'", 'new', 'album', 'come', '22nd', ':(']
# 0	0.11823486	b"panic' new album come 22nd :("
# THE TWEET IS: @Atunci_CoV @QuetaAuthor :( rude
# THE PROCESSED TWEET IS: [':(', 'rude']
# 0	0.11547974	b':( rude'
# THE TWEET IS: @nickiminaj you mention South Africa so many times in your song its about time you come to South Africa ! :(
# THE PROCESSED TWEET IS: ['mention', 'south', 'africa', 'mani', 'time', 'song', 'time', 'come', 'south', 'africa', ':(']
# 0	0.11214982	b'mention south africa mani time song time come south africa :('
# THE TWEET IS: Hate when I can't remember my dreams, I love sharing them :(
# THE PROCESSED TWEET IS: ['hate', "can't", 'rememb', 'dream', 'love', 'share', ':(']
# 0	0.11928842	b"hate can't rememb dream love share :("
# THE TWEET IS: What is going on in America man R.I.P to all the victims in #Louisiana :(
# THE PROCESSED TWEET IS: ['go', 'america', 'man', 'r', 'p', 'victim', 'louisiana', ':(']
# 0	0.11121482	b'go america man r p victim louisiana :('
# THE TWEET IS: When school comes between me and twitter :(
# THE PROCESSED TWEET IS: ['school', 'come', 'twitter', ':(']
# 0	0.11450267	b'school come twitter :('
# THE TWEET IS: Taking 190 at such a horrible timing :(
# THE PROCESSED TWEET IS: ['take', '190', 'horribl', 'time', ':(']
# 0	0.11316338	b'take 190 horribl time :('
# THE TWEET IS: @myungfart ella :( cheer up pls
# THE PROCESSED TWEET IS: ['ella', ':(', 'cheer', 'pl']
# 0	0.11541588	b'ella :( cheer pl'
# THE TWEET IS: @Lizarrdz That's no excuse for launching an attack Lizardz, you should feel like shit for doing that.  I am deeply ashamed of you.  &gt;:(
# THE PROCESSED TWEET IS: ["that'", 'excus', 'launch', 'attack', 'lizardz', 'feel', 'like', 'shit', 'deepli', 'asham', '>:(']
# 0	0.47749248	b"that' excus launch attack lizardz feel like shit deepli asham >:("
# THE TWEET IS: @dtaylor5633  Nothing worse :(
# THE PROCESSED TWEET IS: ['noth', 'wors', ':(']
# 0	0.11504836	b'noth wors :('
# THE TWEET IS: @cockneyradish Sorry about that :( We need to get an emergency engineer out to you! Will you be home for the next 4 hours? ^Laura
# THE PROCESSED TWEET IS: ['sorri', ':(', 'need', 'get', 'emerg', 'engin', 'home', 'next', '4', 'hour', 'laura']
# 0	0.10554532	b'sorri :( need get emerg engin home next 4 hour laura'
# THE TWEET IS: I can never go to sleep early :( lol
# THE PROCESSED TWEET IS: ['never', 'go', 'sleep', 'earli', ':(', 'lol']
# 0	0.10990699	b'never go sleep earli :( lol'
# THE TWEET IS: @elglozano home dormtel near st scho!! all girls siya tho :( do you want me to help you find oneee
# THE PROCESSED TWEET IS: ['home', 'dormtel', 'near', 'st', 'scho', 'girl', 'siya', 'tho', ':(', 'want', 'help', 'find', 'onee']
# 0	0.10545512	b'home dormtel near st scho girl siya tho :( want help find onee'
# THE TWEET IS: @JDRaPlD @Excluzzive I was talking to exclusive :( U know I carry U want me to play 😘
# THE PROCESSED TWEET IS: ['talk', 'exclus', ':(', 'u', 'know', 'carri', 'u', 'want', 'play', '😘']
# 0	0.10641683	b'talk exclus :( u know carri u want play '
# THE TWEET IS: 7pm on a Friday and I am dead :(
# THE PROCESSED TWEET IS: ['7pm', 'friday', 'dead', ':(']
# 0	0.11996653	b'7pm friday dead :('
# THE TWEET IS: @fantasticpru @gemmajoobjoob Sorry Nat, school holidays.. :(  and I'm working at 1pm.
# THE PROCESSED TWEET IS: ['sorri', 'nat', 'school', 'holiday', '..', ':(', "i'm", 'work', '1pm']
# 0	0.10107661	b"sorri nat school holiday .. :( i'm work 1pm"
# THE TWEET IS: @Vitality_Watson why do you do this when Im in work :(
# THE PROCESSED TWEET IS: ['im', 'work', ':(']
# 0	0.11069568	b'im work :('
# THE TWEET IS: @Shansdoe every time i have feta cheese, my head starts to blaaaaze! sometimes my vision is messed too and nausea comes in :(
# THE PROCESSED TWEET IS: ['everi', 'time', 'feta', 'chees', 'head', 'start', 'blaaaz', 'sometim', 'vision', 'mess', 'nausea', 'come', ':(']
# 0	0.11395856	b'everi time feta chees head start blaaaz sometim vision mess nausea come :('
# THE TWEET IS: @natzaz17 Oh no, that's not good :( We're not aware of any issues. Have you been able to top-up now?
# THE PROCESSED TWEET IS: ['oh', "that'", 'good', ':(', "we'r", 'awar', 'issu', 'abl', 'top-up']
# 0	0.11880852	b"oh that' good :( we'r awar issu abl top-up"
# THE TWEET IS: Sharknado, one hour that I will never get back :(
# THE PROCESSED TWEET IS: ['sharknado', 'one', 'hour', 'never', 'get', 'back', ':(']
# 0	0.11007020	b'sharknado one hour never get back :('
# THE TWEET IS: Yeah, leave me on read :-(
# THE PROCESSED TWEET IS: ['yeah', 'leav', 'read', ':-(']
# 0	0.44541857	b'yeah leav read :-('
# THE TWEET IS: I cannot even sleep right now :(
# THE PROCESSED TWEET IS: ['cannot', 'even', 'sleep', 'right', ':(']
# 0	0.11175772	b'cannot even sleep right :('
# THE TWEET IS: And Ernie :(
# THE PROCESSED TWEET IS: ['erni', ':(']
# 0	0.11577318	b'erni :('
# THE TWEET IS: .@ItsFoodsPorn all over my TL :( hungry af!
# THE PROCESSED TWEET IS: ['tl', ':(', 'hungri', 'af']
# 0	0.11455648	b'tl :( hungri af'
# THE TWEET IS: @Marguuuuh it's raining :-(
# THE PROCESSED TWEET IS: ['rain', ':-(']
# 0	0.44511904	b'rain :-('
# THE TWEET IS: @DasCarrot no EZOO for me this year sorry :-(
# THE PROCESSED TWEET IS: ['ezoo', 'year', 'sorri', ':-(']
# 0	0.43259952	b'ezoo year sorri :-('
# THE TWEET IS: Looking for fun? SNAPCHAT : LilyButle18 #snapchat #kikmenow #amateur #kikmeboys #seduce #hannibal #kiksexting :( http://t.co/y8RcKiqSZ3
# THE PROCESSED TWEET IS: ['look', 'fun', 'snapchat', 'lilybutl', '18', 'snapchat', 'kikmenow', 'amateur', 'kikmeboy', 'seduc', 'hannib', 'kiksext', ':(']
# 0	0.11411889	b'look fun snapchat lilybutl 18 snapchat kikmenow amateur kikmeboy seduc hannib kiksext :('
# THE TWEET IS: when ed sheeran is preforming in your country tonight and ur not going :(
# THE PROCESSED TWEET IS: ['ed', 'sheeran', 'preform', 'countri', 'tonight', 'ur', 'go', ':(']
# 0	0.11260202	b'ed sheeran preform countri tonight ur go :('
# THE TWEET IS: @Uber_Mumbai Cannot seem to get one in Powai! :(
# THE PROCESSED TWEET IS: ['cannot', 'seem', 'get', 'one', 'powai', ':(']
# 0	0.11218945	b'cannot seem get one powai :('
# THE TWEET IS: My neighbor doesn't let me sleep :-(
# THE PROCESSED TWEET IS: ['neighbor', 'let', 'sleep', ':-(']
# 0	0.44564464	b'neighbor let sleep :-('
# THE TWEET IS: @The_Lie_Lama back to Delhi :(
# THE PROCESSED TWEET IS: ['back', 'delhi', ':(']
# 0	0.11423494	b'back delhi :('
# THE TWEET IS: @ButtCupboard my feet were cold!!!! and there was no point in taking the socks off okay stop :(
# THE PROCESSED TWEET IS: ['feet', 'cold', 'point', 'take', 'sock', 'okay', 'stop', ':(']
# 0	0.11329209	b'feet cold point take sock okay stop :('
# THE TWEET IS: i can't belieb it's raining :(
# THE PROCESSED TWEET IS: ["can't", 'belieb', 'rain', ':(']
# 0	0.10826910	b"can't belieb rain :("
# THE TWEET IS: Since models own stopped stocking at boots I can't get any and I can't even order online because it's telling me it's unsafe :(
# THE PROCESSED TWEET IS: ['sinc', 'model', 'stop', 'stock', 'boot', "can't", 'get', "can't", 'even', 'order', 'onlin', 'tell', 'unsaf', ':(']
# 0	0.09744641	b"sinc model stop stock boot can't get can't even order onlin tell unsaf :("
# THE TWEET IS: @crushinghes the summer holidays are great but I'm so bored already :(
# THE PROCESSED TWEET IS: ['summer', 'holiday', 'great', "i'm", 'bore', 'alreadi', ':(']
# 0	0.11223938	b"summer holiday great i'm bore alreadi :("
# THE TWEET IS: @X2raw_evicted Oh. I was planning on streaming Halo on Xbox One today.  :(
# THE PROCESSED TWEET IS: ['oh', 'plan', 'stream', 'halo', 'xbox', 'one', 'today', ':(']
# 0	0.11139362	b'oh plan stream halo xbox one today :('
# THE TWEET IS: Drop Dead Fred use to be my favorite movie
# I wish I had it :-(
# THE PROCESSED TWEET IS: ['drop', 'dead', 'fred', 'use', 'favorit', 'movi', 'wish', ':-(']
# 0	0.44324481	b'drop dead fred use favorit movi wish :-('
# THE TWEET IS: remember was #2 on gaon and bad was #6 but infnt are eligible and apink are not :(((( acube why'd u do this
# THE PROCESSED TWEET IS: ['rememb', '2', 'gaon', 'bad', '6', 'infnt', 'elig', 'apink', ':(', 'acub', "why'd", 'u']
# 0	0.11261300	b"rememb 2 gaon bad 6 infnt elig apink :( acub why'd u"
# THE TWEET IS: So sad every time apink has an event .. Don't understand Korean  :( 😭😭
# THE PROCESSED TWEET IS: ['sad', 'everi', 'time', 'apink', 'event', '..', 'understand', 'korean', ':(', '😭', '😭']
# 0	0.10736224	b'sad everi time apink event .. understand korean :(  '
# THE TWEET IS: @iamcharleigh_ :( have fun
# THE PROCESSED TWEET IS: [':(', 'fun']
# 0	0.11705612	b':( fun'
# THE TWEET IS: Bullshit......:((
# THE PROCESSED TWEET IS: ['bullshit', '...', ':(']
# 0	0.11197618	b'bullshit ... :('
# THE TWEET IS: @Taylan247 :( - Do you know what happens to the internet light when the connection drops? Thanks, Kei.
# THE PROCESSED TWEET IS: [':(', 'know', 'happen', 'internet', 'light', 'connect', 'drop', 'thank', 'kei']
# 0	0.13775605	b':( know happen internet light connect drop thank kei'
# THE TWEET IS: @Nigguhjoee @Kvndrewhdz @xEnigma93 I wish I could hear food :(
# THE PROCESSED TWEET IS: ['wish', 'could', 'hear', 'food', ':(']
# 0	0.11170338	b'wish could hear food :('
# THE TWEET IS: @HanaaGhzlli hanaaaa its your birthday???? ya Allah sorry for not wishing you in the van jn i tak tau :( happy birthday gorgeous!
# THE PROCESSED TWEET IS: ['hanaaa', 'birthday', 'ya', 'allah', 'sorri', 'wish', 'van', 'jn', 'tak', 'tau', ':(', 'happi', 'birthday', 'gorgeou']
# 0	0.12003044	b'hanaaa birthday ya allah sorri wish van jn tak tau :( happi birthday gorgeou'
# THE TWEET IS: @redlipshoran @JacobWhitesides omg really? I'm sorry babe :(((
# THE PROCESSED TWEET IS: ['omg', 'realli', "i'm", 'sorri', 'babe', ':(']
# 0	0.09857028	b"omg realli i'm sorri babe :("
# THE TWEET IS: @tallertara what happened soul sis? :(
# THE PROCESSED TWEET IS: ['happen', 'soul', 'si', ':(']
# 0	0.11418108	b'happen soul si :('
# THE TWEET IS: And faith :(
# THE PROCESSED TWEET IS: ['faith', ':(']
# 0	0.11587729	b'faith :('
# THE TWEET IS: What was the last present you received? — haha. basta. :( http://t.co/xhdfobhn8N
# THE PROCESSED TWEET IS: ['last', 'present', 'receiv', '—', 'haha', 'basta', ':(']
# 0	0.11636298	b'last present receiv  haha basta :('
# THE TWEET IS: Went to bed with headache...woke up with headache :(
# THE PROCESSED TWEET IS: ['went', 'bed', 'headach', '...', 'woke', 'headach', ':(']
# 0	0.10977702	b'went bed headach ... woke headach :('
# THE TWEET IS: Snapchat me guys : JasminGarrick #snapchat #kiksexting #chat #sexting #addme #mpoints #hotmusicdelocos :( http://t.co/xXfTQWzhAI
# THE PROCESSED TWEET IS: ['snapchat', 'guy', 'jasmingarrick', 'snapchat', 'kiksext', 'chat', 'sext', 'addm', 'mpoint', 'hotmusicdeloco', ':(']
# 0	0.11201416	b'snapchat guy jasmingarrick snapchat kiksext chat sext addm mpoint hotmusicdeloco :('
# THE TWEET IS: Relation full of lies :(
# THE PROCESSED TWEET IS: ['relat', 'full', 'lie', ':(']
# 0	0.11593340	b'relat full lie :('
# THE TWEET IS: aw fuck there's a dress bag on the floor. dammit that's really loud :(
# THE PROCESSED TWEET IS: ['aw', 'fuck', "there'", 'dress', 'bag', 'floor', 'dammit', "that'", 'realli', 'loud', ':(']
# 0	0.10968448	b"aw fuck there' dress bag floor dammit that' realli loud :("
# THE TWEET IS: Dhis👉 @AhmedMarzooq blocked my twitter :( thank you for the good time 😢 I play 8ball,  FAKMAREY,
# THE PROCESSED TWEET IS: ['dhi', '👉', 'block', 'twitter', ':(', 'thank', 'good', 'time', '😢', 'play', '8ball', 'fakmarey']
# 0	0.14317856	b'dhi  block twitter :( thank good time  play 8ball fakmarey'
# THE TWEET IS: @LaEtchi unfortunately yours smells like doo doo :(
# THE PROCESSED TWEET IS: ['unfortun', 'smell', 'like', 'doo', 'doo', ':(']
# 0	0.11476786	b'unfortun smell like doo doo :('
# THE TWEET IS: I wanna go to six flags :(
# THE PROCESSED TWEET IS: ['wanna', 'go', 'six', 'flag', ':(']
# 0	0.10906596	b'wanna go six flag :('
# THE TWEET IS: @Sam_Ardi sorry :(
# THE PROCESSED TWEET IS: ['sorri', ':(']
# 0	0.10995261	b'sorri :('
# THE TWEET IS: Shopping isn't fun when you're on your own :(
# THE PROCESSED TWEET IS: ['shop', 'fun', ':(']
# 0	0.11724699	b'shop fun :('
# THE TWEET IS: I miss cat :(
# THE PROCESSED TWEET IS: ['miss', 'cat', ':(']
# 0	0.10331672	b'miss cat :('
# THE TWEET IS: @bbgurrll i miss you too :(
# THE PROCESSED TWEET IS: ['miss', ':(']
# 0	0.10369183	b'miss :('
# THE TWEET IS: I would like to be able to work full time on this stuff, but after this move, I'm having to consider taking on a fulltime job. :(
# THE PROCESSED TWEET IS: ['would', 'like', 'abl', 'work', 'full', 'time', 'stuff', 'move', "i'm", 'consid', 'take', 'fulltim', 'job', ':(']
# 0	0.10655464	b"would like abl work full time stuff move i'm consid take fulltim job :("
# THE TWEET IS: @izzsugden yeah I've seen something about tinder on fb!! I was rooting for them :( but the other woman is frustrating me being so awkward!
# THE PROCESSED TWEET IS: ['yeah', "i'v", 'seen', 'someth', 'tinder', 'fb', 'root', ':(', 'woman', 'frustrat', 'awkward']
# 0	0.11238721	b"yeah i'v seen someth tinder fb root :( woman frustrat awkward"
# THE TWEET IS: No food in the kitchen, no money in my wallet (thanks Barcelona) and my dad hasn't been home in a month so no beet juice either :(
# THE PROCESSED TWEET IS: ['food', 'kitchen', 'money', 'wallet', 'thank', 'barcelona', 'dad', 'home', 'month', 'beet', 'juic', 'either', ':(']
# 0	0.13485992	b'food kitchen money wallet thank barcelona dad home month beet juic either :('
# THE TWEET IS: DCI today, now I wish I was going :-(
# THE PROCESSED TWEET IS: ['dci', 'today', 'wish', 'go', ':-(']
# 0	0.43264809	b'dci today wish go :-('
# THE TWEET IS: @TrevvyM114 At work and freezing :(
# THE PROCESSED TWEET IS: ['work', 'freez', ':(']
# 0	0.11458752	b'work freez :('
# THE TWEET IS: Srsly, Y U do that? :((  https://t.co/g0r01GGj2b
# THE PROCESSED TWEET IS: ['srsli', 'u', ':(']
# 0	0.11426351	b'srsli u :('
# THE TWEET IS: Hate seeing my granddad like this :(
# THE PROCESSED TWEET IS: ['hate', 'see', 'granddad', 'like', ':(']
# 0	0.11584009	b'hate see granddad like :('
# THE TWEET IS: @cessyybells sorry pre :(
# THE PROCESSED TWEET IS: ['sorri', 'pre', ':(']
# 0	0.10994649	b'sorri pre :('
# THE TWEET IS: All is fair in love and war kapan update :(
#
# Oh ya udah dihapus. Hilang dari muka bumi.
#
# I want to read it once more someone give me link 😢
# THE PROCESSED TWEET IS: ['fair', 'love', 'war', 'kapan', 'updat', ':(', 'oh', 'ya', 'udah', 'dihapu', 'hilang', 'dari', 'muka', 'bumi', 'want', 'read', 'someon', 'give', 'link', '😢']
# 0	0.11838385	b'fair love war kapan updat :( oh ya udah dihapu hilang dari muka bumi want read someon give link '
# THE TWEET IS: @tiaramescudi girl that was so quick too :(
# THE PROCESSED TWEET IS: ['girl', 'quick', ':(']
# 0	0.11672839	b'girl quick :('
# THE TWEET IS: so many nasty, narrow minded people :(
# THE PROCESSED TWEET IS: ['mani', 'nasti', 'narrow', 'mind', 'peopl', ':(']
# 0	0.11544471	b'mani nasti narrow mind peopl :('
# THE TWEET IS: i want this in my room :-( http://t.co/alpqbVixcP
# THE PROCESSED TWEET IS: ['want', 'room', ':-(']
# 0	0.43062187	b'want room :-('
# THE TWEET IS: Because your friend does not respect your life :-( I'm sorry  https://t.co/ApJ18ZWK0x
# THE PROCESSED TWEET IS: ['friend', 'respect', 'life', ':-(', "i'm", 'sorri']
# 0	0.41681689	b"friend respect life :-( i'm sorri"
# THE TWEET IS: @CollagenShots Sadly not :( @Fighting_Fifty @AmazingPRltd @Janettaras @Gracefodor @NikkiTMB @rozhubley
# THE PROCESSED TWEET IS: ['sadli', ':(']
# 0	0.11525948	b'sadli :('
# THE TWEET IS: Sucks how I'm Gona miss Chellos party :(
# THE PROCESSED TWEET IS: ['suck', "i'm", 'gona', 'miss', 'chello', 'parti', ':(']
# 0	0.09621399	b"suck i'm gona miss chello parti :("
# THE TWEET IS: @RCDeportivo hello, any info about possible interest in Jonathas ?? He is close to join Betis :(
# THE PROCESSED TWEET IS: ['hello', 'info', 'possibl', 'interest', 'jonatha', 'close', 'join', 'beti', ':(']
# 0	0.11979000	b'hello info possibl interest jonatha close join beti :('
# THE TWEET IS: @LizaNMinnelli i can't watch it on my phone. Sorry :( thank you still &lt;3
# THE PROCESSED TWEET IS: ["can't", 'watch', 'phone', 'sorri', ':(', 'thank', 'still', '<3']
# 0	0.12419418	b"can't watch phone sorri :( thank still <3"
# THE TWEET IS: The taxi driver thought me and Sophie worked for Nintendo and took us into the gates :( the security guards gave us the dirtiest looks haha
# THE PROCESSED TWEET IS: ['taxi', 'driver', 'thought', 'sophi', 'work', 'nintendo', 'took', 'us', 'gate', ':(', 'secur', 'guard', 'gave', 'us', 'dirtiest', 'look', 'haha']
# 0	0.12194738	b'taxi driver thought sophi work nintendo took us gate :( secur guard gave us dirtiest look haha'
# THE TWEET IS: @1994sdork omg :-(( I LOVE YOU SO MUCH MONICA SEE YOU SOON AAAHHH !!!
# THE PROCESSED TWEET IS: ['omg', ':-(', 'love', 'much', 'monica', 'see', 'soon', 'aaahhh']
# 0	0.46773336	b'omg :-( love much monica see soon aaahhh'
# THE TWEET IS: :((( (at Crepes 40) — https://t.co/bazEmHlhYL
# THE PROCESSED TWEET IS: [':(', 'crepe', '40', '—']
# 0	0.11597749	b':( crepe 40 '
# THE TWEET IS: @captaintn @JAYBUMAOMGY @satgotlloco @longlivesamd don't kick my bae :((
# THE PROCESSED TWEET IS: ['kick', 'bae', ':(']
# 0	0.11541985	b'kick bae :('
# THE TWEET IS: @JoWaltham haha. Sounds like you’re having fun and games :(
# THE PROCESSED TWEET IS: ['haha', 'sound', 'like', '’', 'fun', 'game', ':(']
# 0	0.11749361	b'haha sound like  fun game :('
# THE TWEET IS: @justinbieber you don't follow me :(
# THE PROCESSED TWEET IS: ['follow', ':(']
# 0	0.11899611	b'follow :('
# THE TWEET IS: school is on monday but i don't wanna meet new people :(
# THE PROCESSED TWEET IS: ['school', 'monday', 'wanna', 'meet', 'new', 'peopl', ':(']
# 0	0.11456944	b'school monday wanna meet new peopl :('
# THE TWEET IS: @exhaustcd BUT... I HAVENT FINISHED YET :(
# THE PROCESSED TWEET IS: ['...', 'havent', 'finish', 'yet', ':(']
# 0	0.11100026	b'... havent finish yet :('
# THE TWEET IS: @bbomiyeh No. U forsaken me and ran off with the other gf. :(
# THE PROCESSED TWEET IS: ['u', 'forsaken', 'ran', 'gf', ':(']
# 0	0.11436960	b'u forsaken ran gf :('
# THE TWEET IS: Kanin please :( xD
# THE PROCESSED TWEET IS: ['kanin', 'pleas', ':(', 'xd']
# 0	0.10642073	b'kanin pleas :( xd'
# THE TWEET IS: Can not get on #hypixel :( want to record grrrr #thestruggleisreal #geek #gamer #gamers #youtube
# THE PROCESSED TWEET IS: ['get', 'hypixel', ':(', 'want', 'record', 'grrr', 'thestruggleisr', 'geek', 'gamer', 'gamer', 'youtub']
# 0	0.10815690	b'get hypixel :( want record grrr thestruggleisr geek gamer gamer youtub'
# THE TWEET IS: @EdmundMcMillenn I want afterbirth now :(
# THE PROCESSED TWEET IS: ['want', 'afterbirth', ':(']
# 0	0.10913199	b'want afterbirth :('
# THE TWEET IS: this is a bummer :( apink's digital + physical sales have been super great but bc of the timing of the album release they aren't up to win?
# THE PROCESSED TWEET IS: ['bummer', ':(', "apink'", 'digit', 'physic', 'sale', 'super', 'great', 'bc', 'time', 'album', 'releas', 'win']
# 0	0.11742870	b"bummer :( apink' digit physic sale super great bc time album releas win"
# THE TWEET IS: this is so sad :((((((((
# THE PROCESSED TWEET IS: ['sad', ':(']
# 0	0.11046712	b'sad :('
# THE TWEET IS: @GarryBrown75 That's awful :( My son missed his physics exam because he had chicken pox and they gave him a predicted grade. Poor girl.
# THE PROCESSED TWEET IS: ["that'", 'aw', ':(', 'son', 'miss', 'physic', 'exam', 'chicken', 'pox', 'gave', 'predict', 'grade', 'poor', 'girl']
# 0	0.10179689	b"that' aw :( son miss physic exam chicken pox gave predict grade poor girl"
# THE TWEET IS: but srsly tho, bae looks so out of it :((((
# THE PROCESSED TWEET IS: ['srsli', 'tho', 'bae', 'look', ':(']
# 0	0.11588786	b'srsli tho bae look :('
# THE TWEET IS: @Cr4sh0v3rr1de Ahm...I've never been to London...nor on a holiday outside of Ireland in nearly 8 years :( Never got the chance/cash to go
# THE PROCESSED TWEET IS: ['ahm', '...', "i'v", 'never', 'london', '...', 'holiday', 'outsid', 'ireland', 'nearli', '8', 'year', ':(', 'never', 'got', 'chanc', 'cash', 'go']
# 0	0.09794044	b"ahm ... i'v never london ... holiday outsid ireland nearli 8 year :( never got chanc cash go"
# THE TWEET IS: please follow me :( @JackJackJohnson
# THE PROCESSED TWEET IS: ['pleas', 'follow', ':(']
# 0	0.10958708	b'pleas follow :('
# THE TWEET IS: @fivedorkz why omg :-(
# THE PROCESSED TWEET IS: ['omg', ':-(']
# 0	0.44282777	b'omg :-('
# THE TWEET IS: 5am &amp; I'm up wit ha damn headache :(
# THE PROCESSED TWEET IS: ['5am', "i'm", 'wit', 'ha', 'damn', 'headach', ':(']
# 0	0.10761118	b"5am i'm wit ha damn headach :("
# THE TWEET IS: I had a dream that I met Karlie Kloss &amp; she was so so sweet &amp; she wanted to take like a bunch of goofy photos with me. :(
# THE PROCESSED TWEET IS: ['dream', 'met', 'karli', 'kloss', 'sweet', 'want', 'take', 'like', 'bunch', 'goofi', 'photo', ':(']
# 0	0.10890523	b'dream met karli kloss sweet want take like bunch goofi photo :('
# THE TWEET IS: i didn't realize it was 3 am i was watching concert videos and pcd is extremely hard rn :(
# THE PROCESSED TWEET IS: ['realiz', '3', 'watch', 'concert', 'video', 'pcd', 'extrem', 'hard', 'rn', ':(']
# 0	0.11360987	b'realiz 3 watch concert video pcd extrem hard rn :('
# THE TWEET IS: @matthaig1 SORRY if I antagonised you with this. But she calls herself a writer. And has had several polite nudges, too... :(
# THE PROCESSED TWEET IS: ['sorri', 'antagonis', 'call', 'writer', 'sever', 'polit', 'nudg', '...', ':(']
# 0	0.10664797	b'sorri antagonis call writer sever polit nudg ... :('
# THE TWEET IS: @helter_skeleton I haven't delved into it enough but what I have seen and heard is fucking horrendous. :(
# THE PROCESSED TWEET IS: ['delv', 'enough', 'seen', 'heard', 'fuck', 'horrend', ':(']
# 0	0.11374371	b'delv enough seen heard fuck horrend :('
# THE TWEET IS: @luke_brooks follow me :(
# THE PROCESSED TWEET IS: ['follow', ':(']
# 0	0.11899611	b'follow :('
# THE TWEET IS: @AdaptsTheGod but duo we both dropped double digits :( TWICE
# THE PROCESSED TWEET IS: ['duo', 'drop', 'doubl', 'digit', ':(', 'twice']
# 0	0.11539432	b'duo drop doubl digit :( twice'
# THE TWEET IS: @DaShawnBullfrog @PapaHogieBear I just got here :( come!!!'
# THE PROCESSED TWEET IS: ['got', ':(', 'come']
# 0	0.11303081	b'got :( come'
# THE TWEET IS: THEYRE SO CUTE I WISH I KNEW WHAT THEY WERE SAYING :( http://t.co/Vr3ICTaFIS
# THE PROCESSED TWEET IS: ['theyr', 'cute', 'wish', 'knew', 'say', ':(']
# 0	0.11248242	b'theyr cute wish knew say :('
# THE TWEET IS: I care :( http://t.co/Oe5ID3cJIR
# THE PROCESSED TWEET IS: ['care', ':(']
# 0	0.11567798	b'care :('
# THE TWEET IS: @Jenna_Marbles I wish I could've met you :(
# THE PROCESSED TWEET IS: ['wish', "could'v", 'met', ':(']
# 0	0.11358613	b"wish could'v met :("
# THE TWEET IS: My grandad really isn't well :( I worry so much about him!
# THE PROCESSED TWEET IS: ['grandad', 'realli', 'well', ':(', 'worri', 'much']
# 0	0.11221277	b'grandad realli well :( worri much'
# THE TWEET IS: @nighteyeslrh and idk what to do bc we have no money if we leave :-(
# THE PROCESSED TWEET IS: ['idk', 'bc', 'money', 'leav', ':-(']
# 0	0.43604975	b'idk bc money leav :-('
# THE TWEET IS: @KyuminpuVELF a lot of people suggest, but they still aren't :(!
# THE PROCESSED TWEET IS: ['lot', 'peopl', 'suggest', 'still', ':(']
# 0	0.11440290	b'lot peopl suggest still :('
# THE TWEET IS: @justinbieber follback me pls :(
# THE PROCESSED TWEET IS: ['follback', 'pl', ':(']
# 0	0.11563960	b'follback pl :('
# THE TWEET IS: @BroderickDamien you have to get a pace maker? oh no! :(
# THE PROCESSED TWEET IS: ['get', 'pace', 'maker', 'oh', ':(']
# 0	0.11230860	b'get pace maker oh :('
# THE TWEET IS: @isalouise2012 ah mince :(
# THE PROCESSED TWEET IS: ['ah', 'minc', ':(']
# 0	0.11550771	b'ah minc :('
# THE TWEET IS: @scdesc Molly deserved a much higher place :(
# THE PROCESSED TWEET IS: ['molli', 'deserv', 'much', 'higher', 'place', ':(']
# 0	0.11365158	b'molli deserv much higher place :('
# THE TWEET IS: I'm so hungry :((
# THE PROCESSED TWEET IS: ["i'm", 'hungri', ':(']
# 0	0.10778399	b"i'm hungri :("
# THE TWEET IS: all i wanna do is have a good time with no one hitting on me or dating me is that too much to ask for :(
# THE PROCESSED TWEET IS: ['wanna', 'good', 'time', 'one', 'hit', 'date', 'much', 'ask', ':(']
# 0	0.11276663	b'wanna good time one hit date much ask :('
# THE TWEET IS: Feeling very sucky w this running nose cough sore throat and fever :-(
# THE PROCESSED TWEET IS: ['feel', 'sucki', 'w', 'run', 'nose', 'cough', 'sore', 'throat', 'fever', ':-(']
# 0	0.43225608	b'feel sucki w run nose cough sore throat fever :-('
# THE TWEET IS: @flirtyoakley same i hate hot weather :( its my graduation ceremony later and all the boys are gonna wear suits everyones going to die
# THE PROCESSED TWEET IS: ['hate', 'hot', 'weather', ':(', 'graduat', 'ceremoni', 'later', 'boy', 'gonna', 'wear', 'suit', 'everyon', 'go', 'die']
# 0	0.10904331	b'hate hot weather :( graduat ceremoni later boy gonna wear suit everyon go die'
# THE TWEET IS: @AlexaBailon "let's go to a party....in our pants " ew :( gross
# THE PROCESSED TWEET IS: ["let'", 'go', 'parti', '...', 'pant', 'ew', ':(', 'gross']
# 0	0.10873920	b"let' go parti ... pant ew :( gross"
# THE TWEET IS: someone has niall layouts to give me? :(
# THE PROCESSED TWEET IS: ['someon', 'niall', 'layout', 'give', ':(']
# 0	0.11565326	b'someon niall layout give :('
# THE TWEET IS: hey christine, why so moody? :(
# THE PROCESSED TWEET IS: ['hey', 'christin', 'moodi', ':(']
# 0	0.11787079	b'hey christin moodi :('
# THE TWEET IS: @bluexxdream i miss you :(
# THE PROCESSED TWEET IS: ['miss', ':(']
# 0	0.10369183	b'miss :('
# THE TWEET IS: THROWBACKS :( http://t.co/WEbrI8gAgM
# THE PROCESSED TWEET IS: ['throwback', ':(']
# 0	0.11593418	b'throwback :('
# THE TWEET IS: @jesuskylie @tothebeyhive thats not a good enough of a reason :( please dont leave youre one of my fav barbs
# THE PROCESSED TWEET IS: ['that', 'good', 'enough', 'reason', ':(', 'pleas', 'dont', 'leav', 'your', 'one', 'fav', 'barb']
# ...
# THE PROCESSED TWEET IS: ['payday', 'feel', 'like', 'payhour', 'gone', 'bill', 'immedi', ':(']
# 0	0.10918846	b'payday feel like payhour gone bill immedi :('
# THE TWEET IS: @Oduun_ lmao :( most natural hair I've seen is ugly I swear
# THE PROCESSED TWEET IS: ['lmao', ':(', 'natur', 'hair', "i'v", 'seen', 'ugli', 'swear']
# 0	0.11181821	b"lmao :( natur hair i'v seen ugli swear"
# THE TWEET IS: @_MeKeLe_ @YogscastLewis Nope :( Best place to get it first is to pre-order on Amazon: http://t.co/fZRCI1xONv
# THE PROCESSED TWEET IS: ['nope', ':(', 'best', 'place', 'get', 'first', 'pre-ord', 'amazon']
# 0	0.11732014	b'nope :( best place get first pre-ord amazon'
# THE TWEET IS: @jobhopjulie I was there on the Sunday for a little while.  Not been able to get up much this year, busy :( all looked great tho!
# THE PROCESSED TWEET IS: ['sunday', 'littl', 'abl', 'get', 'much', 'year', 'busi', ':(', 'look', 'great', 'tho']
# 0	0.11762696	b'sunday littl abl get much year busi :( look great tho'
# THE TWEET IS: @aurorakween you don't fwm :(
# THE PROCESSED TWEET IS: ['fwm', ':(']
# 0	0.11582683	b'fwm :('
# THE TWEET IS: @ShellyBarker123 what's wrong?:((
# THE PROCESSED TWEET IS: ["what'", 'wrong', ':(']
# 0	0.11473746	b"what' wrong :("
# THE TWEET IS: I miss my guppy. :-(
# THE PROCESSED TWEET IS: ['miss', 'guppi', ':-(']
# 0	0.41735614	b'miss guppi :-('
# THE TWEET IS: @Cramdaline It just doesn't go away... you must go to the dentist. :( #poorKid
# THE PROCESSED TWEET IS: ['go', 'away', '...', 'must', 'go', 'dentist', ':(', 'poorkid']
# 0	0.10406653	b'go away ... must go dentist :( poorkid'
# THE TWEET IS: @denocte Thanks - lack of time is a problem, isn't it :(
# THE PROCESSED TWEET IS: ['thank', 'lack', 'time', 'problem', ':(']
# 0	0.13804788	b'thank lack time problem :('
# THE TWEET IS: When you get misunderstood :(
# THE PROCESSED TWEET IS: ['get', 'misunderstood', ':(']
# 0	0.11429045	b'get misunderstood :('
# THE TWEET IS: when ur cat is super nice and cuddly but then suddenly scratches and tries to bite :(
#
# like who can i trust anymore
# THE PROCESSED TWEET IS: ['ur', 'cat', 'super', 'nice', 'cuddli', 'suddenli', 'scratch', 'tri', 'bite', ':(', 'like', 'trust', 'anymor']
# 0	0.11670542	b'ur cat super nice cuddli suddenli scratch tri bite :( like trust anymor'
# THE TWEET IS: I hit my thumb :(.
# THE PROCESSED TWEET IS: ['hit', 'thumb', ':(']
# 0	0.11624711	b'hit thumb :('
# THE TWEET IS: @iloveksoo we almost got to see his cute ankles but his socks :(
# THE PROCESSED TWEET IS: ['almost', 'got', 'see', 'cute', 'ankl', 'sock', ':(']
# 0	0.11488793	b'almost got see cute ankl sock :('
# THE TWEET IS: @bravefrontiergl Honestly at this point I don't care about compensation. I just want to be able to play BF again. :(
# THE PROCESSED TWEET IS: ['honestli', 'point', 'care', 'compens', 'want', 'abl', 'play', 'bf', ':(']
# 0	0.10837570	b'honestli point care compens want abl play bf :('
# THE TWEET IS: @dnwrld that song is not on here :(
# THE PROCESSED TWEET IS: ['song', ':(']
# 0	0.11521166	b'song :('
# THE TWEET IS: @CourtneyR_Green awwwww my baby :( 💕
# THE PROCESSED TWEET IS: ['awww', 'babi', ':(', '💕']
# 0	0.11440511	b'awww babi :( '
# THE TWEET IS: I couldn't sleep last night n it didn't help me waking up at 8 this morning n my phone wasn't even charged :(
# THE PROCESSED TWEET IS: ['sleep', 'last', 'night', 'n', 'help', 'wake', '8', 'morn', 'n', 'phone', 'even', 'charg', ':(']
# 0	0.11261469	b'sleep last night n help wake 8 morn n phone even charg :('
# THE TWEET IS: @ZozeeBo @TanyaBurr please can you tell everyone why you didnt go to vidcon :(
# THE PROCESSED TWEET IS: ['pleas', 'tell', 'everyon', 'didnt', 'go', 'vidcon', ':(']
# 0	0.10326993	b'pleas tell everyon didnt go vidcon :('
# THE TWEET IS: I need to like, tell myself na, na okay lang :((((
# THE PROCESSED TWEET IS: ['need', 'like', 'tell', 'na', 'na', 'okay', 'lang', ':(']
# 0	0.11220276	b'need like tell na na okay lang :('
# THE TWEET IS: @Laraibmufc follow back :(
# THE PROCESSED TWEET IS: ['follow', 'back', ':(']
# 0	0.11736645	b'follow back :('
# THE TWEET IS: my heart is currently torturing itself :( lol wat
# THE PROCESSED TWEET IS: ['heart', 'current', 'tortur', ':(', 'lol', 'wat']
# 0	0.11552135	b'heart current tortur :( lol wat'
# THE TWEET IS: @CallmeHaRsh female student killed in some caste love kirkiri :(
# THE PROCESSED TWEET IS: ['femal', 'student', 'kill', 'cast', 'love', 'kirkiri', ':(']
# 0	0.12630795	b'femal student kill cast love kirkiri :('
# THE TWEET IS: I've run out of bread and I don't feel well enough to make any. :(
# THE PROCESSED TWEET IS: ["i'v", 'run', 'bread', 'feel', 'well', 'enough', 'make', ':(']
# 0	0.10733074	b"i'v run bread feel well enough make :("
# THE TWEET IS: I had a dream of you :( https://t.co/OZdMHNQbSU
# THE PROCESSED TWEET IS: ['dream', ':(']
# 0	0.11571878	b'dream :('
# THE TWEET IS: @UyyChristopher :( Broken hearted? That's just a phase. Don't worry, you can do it!!
# THE PROCESSED TWEET IS: [':(', 'broken', 'heart', "that'", 'phase', 'worri']
# 0	0.11530025	b":( broken heart that' phase worri"
# THE TWEET IS: stop being sour :( it doesn't suit you 😂💞 https://t.co/nJ0ziQ14is
# THE PROCESSED TWEET IS: ['stop', 'sour', ':(', 'suit', '😂', '💞']
# 0	0.11437421	b'stop sour :( suit  '
# THE TWEET IS: wonho reminds me of someone &gt;:( i just cant put my finger to it
# THE PROCESSED TWEET IS: ['wonho', 'remind', 'someon', '>:(', 'cant', 'put', 'finger']
# 0	0.48816000	b'wonho remind someon >:( cant put finger'
# THE TWEET IS: @Coles45Coles
#
# wont be in work today, feel so ill :( i have a tummy bug xx
# THE PROCESSED TWEET IS: ['wont', 'work', 'today', 'feel', 'ill', ':(', 'tummi', 'bug', 'xx']
# 0	0.10890284	b'wont work today feel ill :( tummi bug xx'
# THE TWEET IS: Last day on the beach :-(:-(:-(.... http://t.co/oqo9F7FQs9
# THE PROCESSED TWEET IS: ['last', 'day', 'beach', ':-(', ':-(', ':-(', '...']
# 0	0.34500949	b'last day beach :-( :-( :-( ...'
# THE TWEET IS: RAIN :(
# THE PROCESSED TWEET IS: ['rain', ':(']
# 0	0.11469695	b'rain :('
# THE TWEET IS: @yezzer Visual Studio 2015? it just got out. switched to it already and broke a lot of code :(
# THE PROCESSED TWEET IS: ['visual', 'studio', '2015', 'got', 'switch', 'alreadi', 'broke', 'lot', 'code', ':(']
# 0	0.11521107	b'visual studio 2015 got switch alreadi broke lot code :('
# THE TWEET IS: @MTNza seriously this is unfair some are not asking questions! There are ready to answer and win :( ='(  while we busy asking questions!!
# THE PROCESSED TWEET IS: ['serious', 'unfair', 'ask', 'question', 'readi', 'answer', 'win', ':(', "='(", 'busi', 'ask', 'question']
# 0	0.11573254	b"serious unfair ask question readi answer win :( ='( busi ask question"
# THE TWEET IS: Mission bear: failed again :(
# THE PROCESSED TWEET IS: ['mission', 'bear', 'fail', ':(']
# 0	0.11558681	b'mission bear fail :('
# THE TWEET IS: :-( ugly af :-( https://t.co/bHIXkuNqPS
# THE PROCESSED TWEET IS: [':-(', 'ugli', 'af', ':-(']
# 0	0.39558878	b':-( ugli af :-('
# THE TWEET IS: PAP of your spirit animal? — no i dont have :( http://t.co/0UvPRQnvGl
# THE PROCESSED TWEET IS: ['pap', 'spirit', 'anim', '—', 'dont', ':(']
# 0	0.11440195	b'pap spirit anim  dont :('
# THE TWEET IS: I totally ship #danzell, I'm crafting that I can't go to vidcon, I would sell my soul to the devil to just get a hug from Dan and Phil. :(
# THE PROCESSED TWEET IS: ['total', 'ship', 'danzel', "i'm", 'craft', "can't", 'go', 'vidcon', 'would', 'sell', 'soul', 'devil', 'get', 'hug', 'dan', 'phil', ':(']
# 0	0.09743773	b"total ship danzel i'm craft can't go vidcon would sell soul devil get hug dan phil :("
# THE TWEET IS: @annajudithk Because they hate me | :(
# THE PROCESSED TWEET IS: ['hate', ':(']
# 0	0.11371449	b'hate :('
# THE TWEET IS: @NUFC_Vine he's gona miss Sheff Utd/York probably waiting for a visa which leaves gim with 1 friendly. Bet he starts season on the bench :(
# THE PROCESSED TWEET IS: ["he'", 'gona', 'miss', 'sheff', 'utd', 'york', 'probabl', 'wait', 'visa', 'leav', 'gim', '1', 'friendli', 'bet', 'start', 'season', 'bench', ':(']
# 0	0.10551197	b"he' gona miss sheff utd york probabl wait visa leav gim 1 friendli bet start season bench :("
# THE TWEET IS: @ranaPTX_ BUT WHO WILL LEAD US WHEN YOU'RE GONE :((
# THE PROCESSED TWEET IS: ['lead', 'us', 'gone', ':(']
# 0	0.11810030	b'lead us gone :('
# THE TWEET IS: @LottyStorer @charliee_catlin 😂😩😩 what a mess :(
# THE PROCESSED TWEET IS: ['😂', '😩', '😩', 'mess', ':(']
# 0	0.11410042	b'   mess :('
# THE TWEET IS: @twinitisha irony is its more harmful .. :(
# THE PROCESSED TWEET IS: ['ironi', 'harm', '..', ':(']
# 0	0.11602169	b'ironi harm .. :('
# THE TWEET IS: @DollyyDaydreams I miss you so much more :( xxx
# THE PROCESSED TWEET IS: ['miss', 'much', ':(', 'xxx']
# 0	0.10150197	b'miss much :( xxx'
# THE TWEET IS: no motivation :(
# THE PROCESSED TWEET IS: ['motiv', ':(']
# 0	0.11571636	b'motiv :('
# THE TWEET IS: @LiLGeekette but that is the point. Because it is YOLO I sort of die when lactose is in me... Ugh like 3 months pregnant bloating :(
# THE PROCESSED TWEET IS: ['point', 'yolo', 'sort', 'die', 'lactos', '...', 'ugh', 'like', '3', 'month', 'pregnant', 'bloat', ':(']
# 0	0.10956581	b'point yolo sort die lactos ... ugh like 3 month pregnant bloat :('
# THE TWEET IS: @lovetartan Really sorry I cant find the image you have mentioned :(
# THE PROCESSED TWEET IS: ['realli', 'sorri', 'cant', 'find', 'imag', 'mention', ':(']
# 0	0.10553031	b'realli sorri cant find imag mention :('
# THE TWEET IS: Im not getting ollys tweet notifications :(
# THE PROCESSED TWEET IS: ['im', 'get', 'olli', 'tweet', 'notif', ':(']
# 0	0.11128994	b'im get olli tweet notif :('
# THE TWEET IS: going home tomorrow :-(
# THE PROCESSED TWEET IS: ['go', 'home', 'tomorrow', ':-(']
# 0	0.43436653	b'go home tomorrow :-('
# THE TWEET IS: Too bad I'm poor :( https://t.co/FohWp4P0NN
# THE PROCESSED TWEET IS: ['bad', "i'm", 'poor', ':(']
# 0	0.10509932	b"bad i'm poor :("
# THE TWEET IS: @Glanny_ @RohYB_ @_wattie your team killed me :(
# THE PROCESSED TWEET IS: ['team', 'kill', ':(']
# 0	0.11574360	b'team kill :('
# THE TWEET IS: @MattElyas no way!! :(
# THE PROCESSED TWEET IS: ['way', ':(']
# 0	0.11583488	b'way :('
# THE TWEET IS: i'm so inactive :(
# THE PROCESSED TWEET IS: ["i'm", 'inact', ':(']
# 0	0.10805725	b"i'm inact :("
# THE TWEET IS: :( the world where alternis kills himself is really sad because they leave that place and everyone there just has to die
# THE PROCESSED TWEET IS: [':(', 'world', 'alterni', 'kill', 'realli', 'sad', 'leav', 'place', 'everyon', 'die']
# 0	0.10820435	b':( world alterni kill realli sad leav place everyon die'
# THE TWEET IS: is everyone gonna be talking abt rat boy today bc :((
# THE PROCESSED TWEET IS: ['everyon', 'gonna', 'talk', 'abt', 'rat', 'boy', 'today', 'bc', ':(']
# 0	0.11304268	b'everyon gonna talk abt rat boy today bc :('
# THE TWEET IS: Why on earth did I assume it wouldn't rain in London? Most likely influenced by overall warm and dry past weeks in continental Europe :(
# THE PROCESSED TWEET IS: ['earth', 'assum', 'rain', 'london', 'like', 'influenc', 'overal', 'warm', 'dri', 'past', 'week', 'continent', 'europ', ':(']
# 0	0.11674488	b'earth assum rain london like influenc overal warm dri past week continent europ :('
# THE TWEET IS: I remember when Fab Four had a 24 hour call, Damn I miss that so much :(
# THE PROCESSED TWEET IS: ['rememb', 'fab', 'four', '24', 'hour', 'call', 'damn', 'miss', 'much', ':(']
# 0	0.10030743	b'rememb fab four 24 hour call damn miss much :('
# THE TWEET IS: @dongvvoo1122 😀🔫 r u sure u want that b r u h we barely survive w them in tank tops :((
# THE PROCESSED TWEET IS: ['😀', '🔫', 'r', 'u', 'sure', 'u', 'want', 'b', 'r', 'u', 'h', 'bare', 'surviv', 'w', 'tank', 'top', ':(']
# 0	0.10735068	b'  r u sure u want b r u h bare surviv w tank top :('
# THE TWEET IS: so thirsty :((
# THE PROCESSED TWEET IS: ['thirsti', ':(']
# 0	0.11577318	b'thirsti :('
# THE TWEET IS: @Adam_Bhatti what is a konami policy about PES PC version ?! what happen ?! why all Version are not same ?! :(((
# THE PROCESSED TWEET IS: ['konami', 'polici', 'pe', 'pc', 'version', 'happen', 'version', ':(']
# 0	0.11432748	b'konami polici pe pc version happen version :('
# THE TWEET IS: @AmericanFujoshi doesn't have the sound effects :(
# THE PROCESSED TWEET IS: ['sound', 'effect', ':(']
# 0	0.11587331	b'sound effect :('
# THE TWEET IS: I Blame Rantie For All Of This :(
# THE PROCESSED TWEET IS: ['blame', 'ranti', ':(']
# 0	0.11576998	b'blame ranti :('
# THE TWEET IS: @BlatBlatKLANG ummmm ok?  this is a new development :(
# THE PROCESSED TWEET IS: ['ummm', 'ok', 'new', 'develop', ':(']
# 0	0.11928555	b'ummm ok new develop :('
# THE TWEET IS: You guys are never on :( — Aw sorry we're really bust atm.. Shall be back soon http://t.co/YHfZFhLCgr
# THE PROCESSED TWEET IS: ['guy', 'never', ':(', '—', 'aw', 'sorri', "we'r", 'realli', 'bust', 'atm', '..', 'shall', 'back', 'soon']
# 0	0.10492915	b"guy never :(  aw sorri we'r realli bust atm .. shall back soon"
# THE TWEET IS: @ddlovato @Vevo bad :( I don't like it. This video is  too many perverse.
# THE PROCESSED TWEET IS: ['bad', ':(', 'like', 'video', 'mani', 'pervers']
# 0	0.11371323	b'bad :( like video mani pervers'
# THE TWEET IS: first time to go to school without my bracelets :(( it feels odd
# THE PROCESSED TWEET IS: ['first', 'time', 'go', 'school', 'without', 'bracelet', ':(', 'feel', 'odd']
# 0	0.10452871	b'first time go school without bracelet :( feel odd'
# THE TWEET IS: I can't fall back asleep :(
# THE PROCESSED TWEET IS: ["can't", 'fall', 'back', 'asleep', ':(']
# 0	0.10668951	b"can't fall back asleep :("
# THE TWEET IS: @ayyedolans IM NOT UNTIL THE TWINS FOLLOW ME BACK BYLFNNZ :(
# THE PROCESSED TWEET IS: ['im', 'twin', 'follow', 'back', 'bylfnnz', ':(']
# 0	0.11322498	b'im twin follow back bylfnnz :('
# THE TWEET IS: @PulkitSamrat @yamigautam that is unfair ..why u should banned our all film in Pakistan :(
# THE PROCESSED TWEET IS: ['unfair', '..', 'u', 'ban', 'film', 'pakistan', ':(']
# 0	0.11482196	b'unfair .. u ban film pakistan :('
# THE TWEET IS: @LucyAndLydia @georgiamerryyy I want one :(
# THE PROCESSED TWEET IS: ['want', 'one', ':(']
# 0	0.10741310	b'want one :('
# THE TWEET IS: Feel sick :(
# THE PROCESSED TWEET IS: ['feel', 'sick', ':(']
# 0	0.10853812	b'feel sick :('
# THE TWEET IS: Hmmm 10 mins to get my train and I'm currently about 15 mins away :( #failsatlife
# THE PROCESSED TWEET IS: ['hmmm', '10', 'min', 'get', 'train', "i'm", 'current', '15', 'min', 'away', ':(', 'failsatlif']
# 0	0.10669130	b"hmmm 10 min get train i'm current 15 min away :( failsatlif"
# THE TWEET IS: I'm so hungry :(
# THE PROCESSED TWEET IS: ["i'm", 'hungri', ':(']
# 0	0.10778399	b"i'm hungri :("
# THE TWEET IS: I want it to be my birthday already :(
# THE PROCESSED TWEET IS: ['want', 'birthday', 'alreadi', ':(']
# 0	0.10972417	b'want birthday alreadi :('
# THE TWEET IS: @louanndavies Completely agree. The press won't :(
# THE PROCESSED TWEET IS: ['complet', 'agre', 'press', ':(']
# 0	0.11649397	b'complet agre press :('
# THE TWEET IS: Im super duper tired :(
# THE PROCESSED TWEET IS: ['im', 'super', 'duper', 'tire', ':(']
# 0	0.11047103	b'im super duper tire :('
# THE TWEET IS: Having boring time :( don't know what to do.....
# THE PROCESSED TWEET IS: ['bore', 'time', ':(', 'know', '...']
# 0	0.10996463	b'bore time :( know ...'
# THE TWEET IS: ill be on soon, I PROMISE :(
# waaah
# THE PROCESSED TWEET IS: ['ill', 'soon', 'promis', ':(', 'waaah']
# 0	0.11527947	b'ill soon promis :( waaah'
# THE TWEET IS: I wanna change my avi but uSanele :(
# THE PROCESSED TWEET IS: ['wanna', 'chang', 'avi', 'usanel', ':(']
# 0	0.11243552	b'wanna chang avi usanel :('
# THE TWEET IS: MY PUPPY BROKE HER FOOT :(
# THE PROCESSED TWEET IS: ['puppi', 'broke', 'foot', ':(']
# 0	0.11525629	b'puppi broke foot :('
# THE TWEET IS: where's all the jaebum baby pictures :((
# THE PROCESSED TWEET IS: ["where'", 'jaebum', 'babi', 'pictur', ':(']
# 0	0.11405619	b"where' jaebum babi pictur :("
# THE TWEET IS: But but Mr Ahmad Maslan cooks too :( https://t.co/ArCiD31Zv6
# THE PROCESSED TWEET IS: ['mr', 'ahmad', 'maslan', 'cook', ':(']
# 0	0.11558362	b'mr ahmad maslan cook :('
# THE TWEET IS: @eawoman As a Hull supporter I am expecting a misserable few weeks :-(
# THE PROCESSED TWEET IS: ['hull', 'support', 'expect', 'misser', 'week', ':-(']
# 0	0.45038802	b'hull support expect misser week :-('

# %% [markdown]
# ##**Predict with your own tweet**

# %%
my_tweet = 'This is a ridiculously bright movie. The plot was terrible and I was sad until the ending!'
print(process_tweet(my_tweet))
# Out:
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']

# %%
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
# Out:
# [[0.48139084]]

# %%
if y_hat > 0.5:
    print('Positive sentiment')
else:
    print('Negative sentiment')
# Out:
# Negative sentiment

# %%
my_tweet2 = 'This is amazing, I really loved the plot of movie, it was exciting to watch'
print(process_tweet(my_tweet2))
# Out:
# ['amaz', 'realli', 'love', 'plot', 'movi', 'excit', 'watch']

# %%
y_hat = predict_tweet(my_tweet2, freqs, theta)
print(y_hat)
# Out:
# [[0.52326114]]

# %%
if y_hat > 0.5:
    print('Positive sentiment')
else:
    print('Negative sentiment')
# Out:
# Positive sentiment
